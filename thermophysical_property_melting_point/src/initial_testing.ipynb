# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LinearRegression, Ridge, Lasso, ElasticNet
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_absolute_error
from xgboost import XGBRegressor
from tensorflow.keras.models import Sequential # type: ignore
from tensorflow.keras.layers import Dense, Dropout # type: ignore
from tensorflow.keras.callbacks import EarlyStopping # type: ignore

# %%
pd.set_option('display.max_columns', None)
df = pd.read_csv('../input/train.csv', index_col='id')
X = df.drop(columns=['Tm'])
X = X.drop(columns=['SMILES'])
y = df['Tm']
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

# %%
sc = StandardScaler()
X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)

# %%
lr = LinearRegression()
lr.fit(X_train, y_train)
print(mean_absolute_error(lr.predict(X_test), y_test))
# Out:
# 35.33981329446128

# %%
ridge = Ridge()
ridge.fit(X_train, y_train)
print(mean_absolute_error(ridge.predict(X_test), y_test))
# Out:
# 35.322163300674134

# %%
lasso = Lasso()
lasso.fit(X_train, y_train)
print(mean_absolute_error(lasso.predict(X_test), y_test))
# Out:
# 35.47578373107036

# %%
dt = DecisionTreeRegressor()
dt.fit(X_train, y_train)
print(mean_absolute_error(dt.predict(X_test), y_test))
# Out:
# 43.43711382113821

# %%
rf = RandomForestRegressor()
rf.fit(X_train, y_train)
print(mean_absolute_error(rf.predict(X_test), y_test))
# Out:
# 34.78244393956991

# %%
xgb = XGBRegressor()
xgb.fit(X_train, y_train)
print(mean_absolute_error(xgb.predict(X_test), y_test))
# Out:
# 33.76385109276977

# %%
en = ElasticNet()
en.fit(X_train, y_train)
print(mean_absolute_error(en.predict(X_test), y_test))
# Out:
# 38.95506796641082

# %%
mlp = Sequential()
mlp.add(Dense(units=256, activation='relu', input_shape=(X_train.shape[1],)))
mlp.add(Dropout(0.2))
mlp.add(Dense(units=128, activation='relu'))
mlp.add(Dropout(0.2))
mlp.add(Dense(units=64, activation='relu'))
mlp.add(Dropout(0.2))
mlp.add(Dense(units=32, activation='relu'))
mlp.add(Dropout(0.2))
mlp.add(Dense(units=1))
mlp.compile(loss='mse', optimizer='adam')
early_stop = EarlyStopping(monitor='loss', patience=10, restore_best_weights=True)
mlp.fit(X_train, y_train, batch_size=128, epochs=100, callbacks=[early_stop], verbose=1)
print(mean_absolute_error(mlp.predict(X_test), y_test))
# Out:
# Epoch 1/100
# c:\Users\maxjj\AppData\Local\Programs\Python\Python313\Lib\site-packages\keras\src\layers\core\dense.py:95: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - loss: 81564.4688
# Epoch 2/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 53911.8672
# Epoch 3/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 14858.7998
# Epoch 4/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 8507.5596
# Epoch 5/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 6584.0044
# Epoch 6/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 6109.8218
# Epoch 7/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 5516.3740
# Epoch 8/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 5159.5103
# Epoch 9/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 4753.0278
# Epoch 10/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 4871.1646
# Epoch 11/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 4707.3848
# Epoch 12/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 4561.4272
# Epoch 13/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 4267.1855
# Epoch 14/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 4229.2417
# Epoch 15/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 4174.4336
# Epoch 16/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 4168.1597
# Epoch 17/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 4178.4585
# Epoch 18/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 4196.7646
# Epoch 19/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 4058.3096
# Epoch 20/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 4057.4866
# Epoch 21/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 4040.9858
# Epoch 22/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 3747.5486
# Epoch 23/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 3900.2988
# Epoch 24/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 3838.2078
# Epoch 25/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 3968.7463
# Epoch 26/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 3642.7317
# Epoch 27/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 3926.0852
# Epoch 28/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 3867.7493
# Epoch 29/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 3618.8311
# Epoch 30/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 3587.8918
# Epoch 31/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 3527.4382
# Epoch 32/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 3775.4497
# Epoch 33/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 3647.0769
# Epoch 34/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 3743.6458
# Epoch 35/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 3659.8186
# Epoch 36/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 3674.0796
# Epoch 37/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 3641.5632
# Epoch 38/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 3538.3984
# Epoch 39/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 3742.4128
# Epoch 40/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 3544.9285
# Epoch 41/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 3542.5415
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# 37.730461349630446
